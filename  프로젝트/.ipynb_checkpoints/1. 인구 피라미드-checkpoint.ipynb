# %% [markdown]
# # 1. 인구 피라미드

# %% [markdown]
# ##  남자 데이터 정의

# %%
import pandas as pd
file_name = '201212_201212_연령별인구현황_연간.xlsx'
df_m = pd.read_excel(file_name, skiprows=3, index_col='행정기관', usecols='B,E:Y')
df_m
# Out:
# C:\Users\iljoogns\anaconda3\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#                 0~4세       5~9세     10~14세     15~19세     20~24세     25~29세  \
# 행정기관
# 전국         1,194,460  1,214,863  1,544,170  1,846,162  1,752,677  1,706,803
# 서울특별시        214,127    210,558    265,630    333,823    345,267    397,714
# 부산광역시         68,061     68,759     93,422    123,763    126,824    117,800
# 대구광역시         53,476     58,213     80,184    100,654     96,567     80,995
# 인천광역시         69,665     68,910     85,643    106,084    103,449     98,159
# 광주광역시         36,941     40,661     53,778     62,348     53,296     48,491
# 대전광역시         38,500     40,152     50,574     60,481     56,770     52,801
# 울산광역시         29,919     29,350     38,540     48,960     44,557     38,846
# 세종특별자치시        3,066      2,994      3,305      3,388      3,472      3,495
# 경기도          320,271    327,322    396,148    447,878    408,721    396,689
# 강원도           31,860     35,243     46,837     53,928     54,075     45,918
# 충청북도          37,326     38,012     48,969     57,991     53,343     50,985
# 충청남도          51,101     50,481     62,017     69,236     63,079     65,480
# 전라북도          41,602     44,232     58,983     69,183     62,197     55,472
# 전라남도          41,226     41,827     57,422     67,719     59,215     52,139
# 경상북도          59,348     58,777     76,363     92,533     91,694     84,023
# 경상남도          83,087     82,951    105,672    125,520    111,336    101,306
# 제주특별자치도       14,884     16,421     20,683     22,673     18,815     16,490
#
#               30~34세     35~39세     40~44세     45~49세  ...     55~59세  \
# 행정기관                                                   ...
# 전국         2,078,373  2,085,311  2,366,703  2,143,613  ...  1,689,298
# 서울특별시        476,655    433,603    466,424    404,264  ...    343,207
# 부산광역시        139,444    130,264    148,363    140,591  ...    141,528
# 대구광역시         91,662     96,047    114,180    108,017  ...     84,547
# 인천광역시        120,758    120,789    134,936    127,264  ...     92,667
# 광주광역시         58,681     60,753     67,184     60,018  ...     40,239
# 대전광역시         61,826     63,640     71,521     62,288  ...     48,508
# 울산광역시         49,057     46,632     54,769     55,005  ...     38,997
# 세종특별자치시        4,592      5,024      5,440      4,385  ...      3,874
# 경기도          507,969    538,407    612,383    539,158  ...    362,433
# 강원도           51,435     55,969     68,068     63,585  ...     58,267
# 충청북도          58,842     61,068     69,824     65,032  ...     53,779
# 충청남도          82,461     81,947     91,106     81,254  ...     65,455
# 전라북도          64,057     69,096     81,128     74,771  ...     63,123
# 전라남도          61,942     66,415     81,103     80,846  ...     64,609
# 경상북도          98,036     98,924    116,719    110,646  ...     98,162
# 경상남도         130,252    133,484    155,417    140,746  ...    111,880
# 제주특별자치도       20,704     23,249     28,138     25,743  ...     18,023
#
#               60~64세   65~69세   70~74세   75~79세   80~84세  85~89세  90~94세  \
# 행정기관
# 전국         1,189,791  893,794  779,224  467,062  210,864  81,249  25,325
# 서울특별시        247,439  191,499  153,800   80,347   35,037  13,915   5,098
# 부산광역시        104,575   75,014   60,041   32,074   13,515   4,575   1,301
# 대구광역시         61,288   41,231   36,065   21,207    8,987   3,261     814
# 인천광역시         59,134   43,013   33,449   19,489    8,886   3,653   1,292
# 광주광역시         30,084   22,658   18,868   10,487    4,798   1,837     469
# 대전광역시         32,237   22,317   18,528   11,005    4,990   1,998     626
# 울산광역시         25,021   15,180   11,292    5,664    2,384     757     224
# 세종특별자치시        2,808    2,109    2,195    1,542      724     289      88
# 경기도          229,929  174,784  147,104   89,179   40,169  15,770   5,387
# 강원도           37,200   33,954   32,540   19,568    8,321   3,835   1,278
# 충청북도          36,506   28,492   28,026   18,590    7,900   3,213     961
# 충청남도          50,054   38,574   38,691   28,856   13,838   5,111   1,463
# 전라북도          49,827   39,156   37,743   25,422   12,342   4,725   1,305
# 전라남도          55,046   44,588   46,488   28,962   14,418   5,256   1,454
# 경상북도          75,833   54,351   55,557   36,739   17,276   6,830   1,891
# 경상남도          79,886   55,846   49,656   32,027   14,990   5,495   1,400
# 제주특별자치도       12,924   11,028    9,181    5,904    2,289     729     274
#
#           95~99세 100세 이상
# 행정기관
# 전국         5,142   2,908
# 서울특별시      1,259     996
# 부산광역시        282     256
# 대구광역시        164      83
# 인천광역시        255     132
# 광주광역시         69      34
# 대전광역시        140      50
# 울산광역시         46      14
# 세종특별자치시       14      16
# 경기도        1,067     613
# 강원도          277     159
# 충청북도         193      82
# 충청남도         286     104
# 전라북도         197      97
# 전라남도         241      65
# 경상북도         356     117
# 경상남도         236      69
# 제주특별자치도       60      21
#
# [18 rows x 21 columns]

# %%
df_m.iloc[0] = df_m.iloc[0].str.replace(',','').astype(int)  # 1. 1.195.951 => 1195951(정수형)
df_m.iloc[0]
# Out:
# 0~4세       1194460
# 5~9세       1214863
# 10~14세     1544170
# 15~19세     1846162
# 20~24세     1752677
# 25~29세     1706803
# 30~34세     2078373
# 35~39세     2085311
# 40~44세     2366703
# 45~49세     2143613
# 50~54세     2226268
# 55~59세     1689298
# 60~64세     1189791
# 65~69세      893794
# 70~74세      779224
# 75~79세      467062
# 80~84세      210864
# 85~89세       81249
# 90~94세       25325
# 95~99세        5142
# 100세 이상       2908
# Name: 전국  , dtype: object

# %%
df_m.iloc[0]
# Out:
# 0~4세       1194460
# 5~9세       1214863
# 10~14세     1544170
# 15~19세     1846162
# 20~24세     1752677
# 25~29세     1706803
# 30~34세     2078373
# 35~39세     2085311
# 40~44세     2366703
# 45~49세     2143613
# 50~54세     2226268
# 55~59세     1689298
# 60~64세     1189791
# 65~69세      893794
# 70~74세      779224
# 75~79세      467062
# 80~84세      210864
# 85~89세       81249
# 90~94세       25325
# 95~99세        5142
# 100세 이상       2908
# Name: 전국  , dtype: object

# %% [markdown]
# ## 여자 데이터 정의

# %%
df_w = pd.read_excel(file_name, skiprows=3, index_col='행정기관', usecols='B,AB:AV')
df_w.head(3)
# Out:
# C:\Users\iljoogns\anaconda3\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#             0~4세.1     5~9세.1   10~14세.1   15~19세.1   20~24세.1   25~29세.1  \
# 행정기관
# 전국       1,126,833  1,132,555  1,411,806  1,645,141  1,566,863  1,600,605
# 서울특별시      202,979    198,323    245,316    301,740    338,720    407,243
# 부산광역시       64,592     64,022     83,884    106,253    110,969    111,181
#
#           30~34세.1   35~39세.1   40~44세.1   45~49세.1  ...   55~59세.1  \
# 행정기관                                                 ...
# 전국       1,984,225  2,021,034  2,273,044  2,052,798  ...  1,696,804
# 서울특별시      467,077    424,907    459,616    405,475  ...    370,318
# 부산광역시      132,831    126,819    149,037    145,578  ...    148,386
#
#           60~64세.1   65~69세.1 70~74세.1 75~79세.1 80~84세.1 85~89세.1 90~94세.1  \
# 행정기관
# 전국       1,238,812  1,006,139  995,119  728,938  452,768  220,210   81,261
# 서울특별시      266,499    210,295  172,628  113,264   69,784   36,400   14,200
# 부산광역시      110,332     81,429   73,504   49,198   29,950   14,342    4,594
#
#         95~99세.1 100세 이상.1
# 행정기관
# 전국        20,308     9,749
# 서울특별시      4,131     2,930
# 부산광역시      1,197       927
#
# [3 rows x 21 columns]

# %%
 df_m.columns
# Out:
# Index(['0~4세', '5~9세', '10~14세', '15~19세', '20~24세', '25~29세', '30~34세',
#        '35~39세', '40~44세', '45~49세', '50~54세', '55~59세', '60~64세', '65~69세',
#        '70~74세', '75~79세', '80~84세', '85~89세', '90~94세', '95~99세', '100세 이상'],
#       dtype='object')

# %%
 df_w.columns
# Out:
# Index(['0~4세.1', '5~9세.1', '10~14세.1', '15~19세.1', '20~24세.1', '25~29세.1',
#        '30~34세.1', '35~39세.1', '40~44세.1', '45~49세.1', '50~54세.1', '55~59세.1',
#        '60~64세.1', '65~69세.1', '70~74세.1', '75~79세.1', '80~84세.1', '85~89세.1',
#        '90~94세.1', '95~99세.1', '100세 이상.1'],
#       dtype='object')

# %%
 df_w.columns= df_m.columns

# %%
 df_w.columns
# Out:
# Index(['0~4세', '5~9세', '10~14세', '15~19세', '20~24세', '25~29세', '30~34세',
#        '35~39세', '40~44세', '45~49세', '50~54세', '55~59세', '60~64세', '65~69세',
#        '70~74세', '75~79세', '80~84세', '85~89세', '90~94세', '95~99세', '100세 이상'],
#       dtype='object')

# %%
df_w.iloc[0] = df_w.iloc[0].str.replace(',','').astype(int)  # 1. 1.195.951 => 1195951(정수형)
df_w.iloc[0]
# Out:
# 0~4세       1126833
# 5~9세       1132555
# 10~14세     1411806
# 15~19세     1645141
# 20~24세     1566863
# 25~29세     1600605
# 30~34세     1984225
# 35~39세     2021034
# 40~44세     2273044
# 45~49세     2052798
# 50~54세     2179200
# 55~59세     1696804
# 60~64세     1238812
# 65~69세     1006139
# 70~74세      995119
# 75~79세      728938
# 80~84세      452768
# 85~89세      220210
# 90~94세       81261
# 95~99세       20308
# 100세 이상       9749
# Name: 전국  , dtype: object

# %% [markdown]
# ## 데이터 시각화

# %%
import matplotlib.pyplot as plt
import matplotlib
matplotlib.rcParams['font.family'] = 'Malgun Gothic'
matplotlib.rcParams['font.size'] = 15
matplotlib.rcParams['axes.unicode_minus'] = False

# %%
plt.figure(figsize=(10,7))
plt.barh(df_m.columns, -df_m.iloc[0] // 1000) # (단위:  천 명)
plt.barh(df_w.columns, df_w.iloc[0] // 1000) # (단위:  천 명)
plt.title('2012 대한민국 인구 피라미드')
plt.savefig('2012_인구피라미드.png', dpi=100)
plt.show()
